# %%
import re

# %%
a="Hello this is Data Science class and you can contact this number 7894561230"
re.findall("\d+",a)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14472\1805762765.py:2: SyntaxWarning: invalid escape sequence '\d'
#   re.findall("\d+",a)
# ['7894561230']

# %%
re.search("Data Science",a)
# Out:
# <re.Match object; span=(14, 26), match='Data Science'>

# %%
c1 = re.sub("a","**",a)
c1
# Out:
# 'Hello this is D**t** Science cl**ss **nd you c**n cont**ct this number 7894561230'

# %%
c= re.match(r"Hello",a)
c.group()
# Out:
# 'Hello'

# %%
a="Hello this is Data Science class and you can contact this number 7894561230"
re.findall("\D",a)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14472\72592737.py:2: SyntaxWarning: invalid escape sequence '\D'
#   re.findall("\D",a)
# ['H',
#  'e',
#  'l',
#  'l',
#  'o',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  'c',
#  'l',
#  'a',
#  's',
#  's',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'y',
#  'o',
#  'u',
#  ' ',
#  'c',
#  'a',
#  'n',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'a',
#  'c',
#  't',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'n',
#  'u',
#  'm',
#  'b',
#  'e',
#  'r',
#  ' ']

# %%
a="Hello this is Data Science class and you can contact this number 7894561230"
re.findall("\s",a)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14472\1604205740.py:2: SyntaxWarning: invalid escape sequence '\s'
#   re.findall("\s",a)
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
a="Hello this is Data Science class and you can contact this number 7894561230"
re.findall("\S+",a)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14472\317629720.py:2: SyntaxWarning: invalid escape sequence '\S'
#   re.findall("\S+",a)
# ['Hello',
#  'this',
#  'is',
#  'Data',
#  'Science',
#  'class',
#  'and',
#  'you',
#  'can',
#  'contact',
#  'this',
#  'number',
#  '7894561230']
